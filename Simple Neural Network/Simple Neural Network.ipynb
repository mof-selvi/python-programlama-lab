# %%
# Muhammed Ömer Faruk Selvi


#%%
import numpy as np

def rnd(x):
    return round(x,2)
def rndarr(arr,precision=2):
    return np.round_(arr, decimals=precision)
def prnt(mtr):
    print(mtr,"\n", rndarr(globals()[mtr], 4))



# sonlu farklar yaklaşımı ile autodiff
def derivative(f, x, y, axis=1, x_eps=0.00001, y_eps=0.0):
    results = []
    for i in range(len(y)):
        for j in range(len(y[0])):
            results.append(derivative_val(f,np.array([x[i][j]]),np.array([y[i][j]])))
    return np.array([results])

# yöntemi anlatan bir kaynak: "Scikit-Learn, Keras ve Tensorflow ile Uygulamalı Makine Öğrenmesi", Aurelien Geron, s.814
def derivative_val(f, x, y, axis=1, x_eps=0.00001, y_eps=0.0):
    return (f(x+x_eps, y+y_eps) - f(x,y))/(x_eps + y_eps)




# sigmoid aktivasyon fonksiyonu
def sigmoid(val):
    return 1.0 / (1.0 + np.exp(-val))

# sigmoid'in türevi (biri A diğeri Z için kullanılabilir)
def sigmoid_d_z(val):
    return val * (1.0 - val)

def sigmoid_d(val):
    return sigmoid(val) * (1.0 - sigmoid(val))




# mult = np.sum(np.dot(dataset_x, W_hl.T), axis=1) 
# mult2 = mult + B_hl

def loss_function_mse(y_prediction, y_truth):
    len_ = len(y_truth)
    return np.sum((y_prediction-y_truth)**2) / len_


# def loss_function_mse_d(y_prediction, y_truth):
# #     len_ = len(y_truth)
#     return (y_prediction-y_truth)

def loss_function_mse_d(y_prediction, y_truth):
    return 2*(y_prediction-y_truth)


# kaynak: https://stackoverflow.com/a/67616451
def loss_function_bce(y_truth, y_prediction):
    term_0 = (1-y_truth) * np.log(1-y_prediction + 1e-7)
    term_1 = y_truth * np.log(y_prediction + 1e-7)
    return -np.mean(term_0+term_1, axis=0)

def loss_function_bce_d(y_prediction, y_truth):
    return -(y_truth/y_prediction + 1e-7) + (1-y_truth)/(1-y_prediction + 1e-7)
# kaynak: http://neuralnetworksanddeeplearning.com/chap3.html#introducing_the_cross-entropy_cost_function
# def loss_function_bce_d(y_prediction, y_truth):
#     return derivative(loss_function_bce,y_prediction,y_truth)


def prediction(data_x, data_y):
    global Z_hl, A_hl, Z_op, A_op
    
    perceptron_value = np.dot(data_x, W_hl) + B_hl
    Pred_hl = sigmoid(perceptron_value)
    
    Z_hl = perceptron_value
    A_hl = Pred_hl

    # print(perceptron_value)
    # print(prediction)
        
#     print("W_op",W_op)
#     print("Pred_hl",Pred_hl)
    
    perceptron_value2 = np.dot(Pred_hl, W_op) + B_op
#     print("perceptron_value2",perceptron_value2)
    # Pred_op = sigmoid(perceptron_value2)
    Pred_op = perceptron_value2
    
    Z_op = perceptron_value2
    A_op = Pred_op
    prnt("A_op")
    print(data_y)
    
#     print("Loss:",loss_function_mse(Pred_op,data_y))

    


################ DATA
dataset_x = [
    [0,0],
    [0,1],
    [1,0],
    [1,1]
]

dataset_y = [
    [0,0],
    [1,1],
    [1,1],
    [0,1]
]

dataset_x = np.array(dataset_x)
dataset_y = np.array(dataset_y)

sample_count = dataset_y.shape[0]

learning_rate = 0.1

batch_size = 1 #stochastic

# %%
# Network 1
# Çıkışta aktivasyon yok
# Loss: MSE

print("#"*50)
print("Network 1")
print("#"*50)


# bir gizli katmanımız ve bir çıktı katmanımız var
# gizli katman 3 nöronlu; yani her bir girdi nöronundan üçer bağlantı başlar

W_hl = rndarr(np.random.random((2, 3))) # gizli katmana giden ağırlıklar
B_hl = rndarr(np.random.random((3))) # gizli katman için bias
Z_hl = np.zeros((3)) # gizli katman sonucu (inaktif)
A_hl = np.zeros((3)) # gizli katman sonucu
D_hl = np.random.random((2, 3)) # gizli katmana giden ağırlıklarının deltaları

W_op = rndarr(np.random.random((3, 2))) # çıktı katmanına giden ağırlıklar
B_op = rndarr(np.random.random((2))) # çıktı katmanı için bias
Z_op = np.zeros((2)) # çıktı katmanı sonucu (inaktif)
A_op = np.zeros((2)) # çıktı katmanı sonucu
D_op = np.random.random((3, 2)) # çıktı katmanına giden ağırlıkların deltaları

####### DATA




print("Weights and biases before starting:")
prnt("W_op")
prnt("W_hl")
prnt("B_op")
prnt("B_hl")
print("\n\n")

for epoch in range(1,51):
    print("\t Training... Epoch",epoch)
    for bno in range(0,sample_count,batch_size):
        
        print("Passing samples in the range of",bno,":",bno+batch_size)
        i_low = bno
        i_high = bno+batch_size
        if i_high > sample_count:
            i_high = sample_count
        batch_x = dataset_x[i_low:i_high]
        batch_y = dataset_y[i_low:i_high]
        # print(batch_x,batch_y,"\n\n\n")
        
    
        prediction(batch_x, batch_y)

        # print("A_op",A_op)
        # error = (batch_y[i] - A_op)**2
        error = loss_function_mse(A_op, batch_y)
        D_op = loss_function_mse_d(A_op, batch_y)
#         prnt("A_op")
#         prnt("batch_y")
#         prnt("D_op")
#         D_op = derivative(loss_function_mse,A_op, batch_y) # aynı sonucu veriyor
#         prnt("D_op")
        # prnt("delta_by")
        # print("A_hl",A_hl)
        delta_wy = np.array([np.outer(D_op[a],A_hl[a]) for a in range(len(D_op))])
        delta_wy = np.average(delta_wy,axis=0).T
        # print("delta_wy",delta_wy)
        delta_by = np.average(D_op,axis=0).T


        D_hl = np.dot(D_op, W_op.T)
        D_hl = np.multiply(D_hl, sigmoid_d(A_hl))
        # print("D_hl",D_hl)
        delta_wh = np.array([np.outer(D_hl[a],batch_x[a]) for a in range(len(D_hl))])
        delta_wh = np.average(delta_wh,axis=0).T
        # print("delta_wh",delta_wh)
        delta_bh = np.average(D_hl,axis=0).T


        # print("W_op",W_op)
        # print("W_hl",W_hl)
        # error2 = loss_function_mse(A_op, batch_y[i])
        # delta_op = np.dot(batch_x, error * sigmoid_d(A_op))


        W_op -= learning_rate * delta_wy
        W_hl -= learning_rate * delta_wh


        B_op -= learning_rate * delta_by
        B_hl -= learning_rate * delta_bh

    
    prnt("W_op")
    prnt("W_hl")
    prnt("B_op")
    prnt("B_hl")
    prediction(dataset_x, dataset_y)
    print("Loss:",loss_function_mse(A_op,dataset_y))
    print("\n")


print("\n\nDone! Final prediction result:")
prediction(dataset_x, dataset_y)
print("Loss:",loss_function_mse(A_op,dataset_y))
# print(A_op)
# Out:
# ##################################################
# Network 1
# ##################################################
# Weights and biases before starting:
# W_op
#  [[0.78 0.52]
#  [0.59 0.49]
#  [0.79 0.64]]
# W_hl
#  [[0.13 0.93 0.37]
#  [0.49 0.69 0.6 ]]
# B_op
#  [0.69 0.94]
# B_hl
#  [0.43 0.42 0.05]
#
#
#
# 	 Training... Epoch 1
# Passing samples in the range of 0 : 1
# A_op
#  [[1.9235 1.8788]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[1.3183 1.2405]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[1.1035 1.0881]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[1.2077 1.1484]]
# [[0 1]]
# W_op
#  [[0.3182 0.2272]
#  [0.0842 0.1883]
#  [0.3715 0.3864]]
# W_hl
#  [[0.0988 0.9116 0.334 ]
#  [0.4514 0.6661 0.5549]]
# B_op
#  [-0.0206  0.4688]
# B_hl
#  [ 0.2748  0.2999 -0.127 ]
# A_op
#  [[0.3826 0.8871]
#  [0.4797 0.9923]
#  [0.4377 0.9617]
#  [0.527  1.0536]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4505633955303664
#
#
# 	 Training... Epoch 2
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3826 0.8871]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.3176 0.6206]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5923 0.7726]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.9045 0.9661]]
# [[0 1]]
# W_op
#  [[0.2878 0.2089]
#  [0.0446 0.1821]
#  [0.3378 0.3785]]
# W_hl
#  [[0.0912 0.9081 0.3276]
#  [0.4456 0.6614 0.5526]]
# B_op
#  [-0.06    0.4196]
# B_hl
#  [ 0.2628  0.2898 -0.1406]
# A_op
#  [[0.2853 0.8178]
#  [0.3682 0.9186]
#  [0.328  0.8891]
#  [0.4058 0.9775]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4462406818777924
#
#
# 	 Training... Epoch 3
# Passing samples in the range of 0 : 1
# A_op
#  [[0.2853 0.8178]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.248 0.578]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5536 0.7491]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8785 0.9545]]
# [[0 1]]
# W_op
#  [[0.2861 0.2086]
#  [0.0366 0.1957]
#  [0.3294 0.3864]]
# W_hl
#  [[0.085  0.9055 0.3231]
#  [0.4409 0.6569 0.5523]]
# B_op
#  [-0.0531  0.3997]
# B_hl
#  [ 0.2557  0.2818 -0.1477]
# A_op
#  [[0.2816 0.8078]
#  [0.3618 0.9114]
#  [0.3213 0.8817]
#  [0.3969 0.9723]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.44498743928428164
#
#
# 	 Training... Epoch 4
# Passing samples in the range of 0 : 1
# A_op
#  [[0.2816 0.8078]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2435 0.5761]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5494 0.747 ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8734 0.9559]]
# [[0 1]]
# W_op
#  [[0.2867 0.2096]
#  [0.0311 0.2108]
#  [0.3231 0.3956]]
# W_hl
#  [[0.0789 0.9032 0.3192]
#  [0.4363 0.6527 0.5524]]
# B_op
#  [-0.0427  0.3823]
# B_hl
#  [ 0.249   0.2739 -0.1543]
# A_op
#  [[0.2852 0.8024]
#  [0.3635 0.9094]
#  [0.3225 0.8793]
#  [0.3968 0.9728]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.44256625334885014
#
#
# 	 Training... Epoch 5
# Passing samples in the range of 0 : 1
# A_op
#  [[0.2852 0.8024]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2441 0.5773]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5479 0.7466]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8701 0.9583]]
# [[0 1]]
# W_op
#  [[0.2875 0.2106]
#  [0.0257 0.2259]
#  [0.3169 0.4048]]
# W_hl
#  [[0.0729 0.9013 0.3155]
#  [0.4318 0.6489 0.5528]]
# B_op
#  [-0.0321  0.3654]
# B_hl
#  [ 0.2423  0.2659 -0.1609]
# A_op
#  [[0.2892 0.7974]
#  [0.3658 0.9078]
#  [0.3244 0.8775]
#  [0.3973 0.9738]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.44009274673993104
#
#
# 	 Training... Epoch 6
# Passing samples in the range of 0 : 1
# A_op
#  [[0.2892 0.7974]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2452 0.5787]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5467 0.7464]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8669 0.9608]]
# [[0 1]]
# W_op
#  [[0.2883 0.2115]
#  [0.0203 0.241 ]
#  [0.3108 0.4139]]
# W_hl
#  [[0.067  0.8997 0.3122]
#  [0.4274 0.6454 0.5534]]
# B_op
#  [-0.0217  0.3487]
# B_hl
#  [ 0.2358  0.2579 -0.1675]
# A_op
#  [[0.2932 0.7925]
#  [0.368  0.9062]
#  [0.3262 0.8757]
#  [0.3978 0.9748]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4376598780462158
#
#
# 	 Training... Epoch 7
# Passing samples in the range of 0 : 1
# A_op
#  [[0.2932 0.7925]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2462 0.5802]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5455 0.7463]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8638 0.9633]]
# [[0 1]]
# W_op
#  [[0.2892 0.2123]
#  [0.0149 0.256 ]
#  [0.3048 0.423 ]]
# W_hl
#  [[0.0612 0.8984 0.3091]
#  [0.423  0.6423 0.5542]]
# B_op
#  [-0.0115  0.3323]
# B_hl
#  [ 0.2292  0.2499 -0.174 ]
# A_op
#  [[0.2972 0.7876]
#  [0.3703 0.9047]
#  [0.328  0.8739]
#  [0.3983 0.9758]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.435271610801345
#
#
# 	 Training... Epoch 8
# Passing samples in the range of 0 : 1
# A_op
#  [[0.2972 0.7876]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2473 0.5816]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5443 0.7461]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8608 0.9659]]
# [[0 1]]
# W_op
#  [[0.2902 0.2131]
#  [0.0094 0.271 ]
#  [0.2989 0.432 ]]
# W_hl
#  [[0.0554 0.8973 0.3063]
#  [0.4187 0.6395 0.5552]]
# B_op
#  [-0.0014  0.316 ]
# B_hl
#  [ 0.2228  0.2418 -0.1806]
# A_op
#  [[0.301  0.7827]
#  [0.3724 0.9032]
#  [0.3297 0.8721]
#  [0.3988 0.9769]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4329249743003064
#
#
# 	 Training... Epoch 9
# Passing samples in the range of 0 : 1
# A_op
#  [[0.301  0.7827]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2483 0.583 ]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5432 0.746 ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8578 0.9685]]
# [[0 1]]
# W_op
#  [[0.2912 0.2137]
#  [0.0039 0.2859]
#  [0.293  0.4409]]
# W_hl
#  [[0.0497 0.8966 0.3038]
#  [0.4145 0.6371 0.5564]]
# B_op
#  [0.0085 0.3   ]
# B_hl
#  [ 0.2163  0.2337 -0.1872]
# A_op
#  [[0.3048 0.7778]
#  [0.3745 0.9017]
#  [0.3313 0.8704]
#  [0.3992 0.978 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.43061665828189205
#
#
# 	 Training... Epoch 10
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3048 0.7778]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2493 0.5844]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5421 0.7459]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8548 0.9712]]
# [[0 1]]
# W_op
#  [[ 0.2922  0.2142]
#  [-0.0016  0.3008]
#  [ 0.2871  0.4499]]
# W_hl
#  [[0.0441 0.8961 0.3015]
#  [0.4103 0.6349 0.5578]]
# B_op
#  [0.0183 0.2841]
# B_hl
#  [ 0.21    0.2255 -0.1938]
# A_op
#  [[0.3085 0.7729]
#  [0.3766 0.9002]
#  [0.3329 0.8686]
#  [0.3995 0.9792]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4283435417397808
#
#
# 	 Training... Epoch 11
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3085 0.7729]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2503 0.5857]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.541  0.7458]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8519 0.9738]]
# [[0 1]]
# W_op
#  [[ 0.2933  0.2145]
#  [-0.0072  0.3156]
#  [ 0.2813  0.4587]]
# W_hl
#  [[0.0384 0.8959 0.2994]
#  [0.4061 0.6331 0.5595]]
# B_op
#  [0.028  0.2685]
# B_hl
#  [ 0.2036  0.2173 -0.2004]
# A_op
#  [[0.3121 0.768 ]
#  [0.3786 0.8987]
#  [0.3345 0.8669]
#  [0.3998 0.9803]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.42610273035152546
#
#
# 	 Training... Epoch 12
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3121 0.768 ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2512 0.5871]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5399 0.7457]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8491 0.9766]]
# [[0 1]]
# W_op
#  [[ 0.2944  0.2148]
#  [-0.0127  0.3303]
#  [ 0.2755  0.4676]]
# W_hl
#  [[0.0329 0.896  0.2977]
#  [0.402  0.6315 0.5613]]
# B_op
#  [0.0375 0.253 ]
# B_hl
#  [ 0.1974  0.2091 -0.207 ]
# A_op
#  [[0.3157 0.763 ]
#  [0.3806 0.8972]
#  [0.336  0.8652]
#  [0.4001 0.9815]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4238915538344152
#
#
# 	 Training... Epoch 13
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3157 0.763 ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2522 0.5884]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5389 0.7457]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8462 0.9793]]
# [[0 1]]
# W_op
#  [[ 0.2956  0.215 ]
#  [-0.0183  0.345 ]
#  [ 0.2698  0.4763]]
# W_hl
#  [[0.0274 0.8963 0.2961]
#  [0.3979 0.6303 0.5632]]
# B_op
#  [0.0469 0.2377]
# B_hl
#  [ 0.1911  0.2009 -0.2136]
# A_op
#  [[0.3192 0.7581]
#  [0.3825 0.8957]
#  [0.3375 0.8636]
#  [0.4003 0.9828]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.42170756031686035
#
#
# 	 Training... Epoch 14
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3192 0.7581]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2531 0.5897]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5379 0.7457]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8434 0.9821]]
# [[0 1]]
# W_op
#  [[ 0.2968  0.215 ]
#  [-0.0239  0.3597]
#  [ 0.264   0.4851]]
# W_hl
#  [[0.0219 0.8969 0.2948]
#  [0.3939 0.6293 0.5654]]
# B_op
#  [0.0562 0.2226]
# B_hl
#  [ 0.1849  0.1926 -0.2202]
# A_op
#  [[0.3227 0.7531]
#  [0.3843 0.8942]
#  [0.3389 0.8619]
#  [0.4005 0.9841]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.41954851076640537
#
#
# 	 Training... Epoch 15
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3227 0.7531]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.254  0.5911]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5368 0.7457]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8407 0.9849]]
# [[0 1]]
# W_op
#  [[ 0.2981  0.215 ]
#  [-0.0295  0.3743]
#  [ 0.2584  0.4938]]
# W_hl
#  [[0.0164 0.8978 0.2937]
#  [0.3899 0.6286 0.5677]]
# B_op
#  [0.0653 0.2076]
# B_hl
#  [ 0.1788  0.1843 -0.2268]
# A_op
#  [[0.3261 0.7481]
#  [0.3862 0.8927]
#  [0.3403 0.8603]
#  [0.4006 0.9854]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.417412373669581
#
#
# 	 Training... Epoch 16
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3261 0.7481]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2549 0.5923]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5359 0.7457]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.838  0.9878]]
# [[0 1]]
# W_op
#  [[ 0.2994  0.2148]
#  [-0.0352  0.3888]
#  [ 0.2527  0.5025]]
# W_hl
#  [[0.011  0.8988 0.2928]
#  [0.3859 0.6282 0.5702]]
# B_op
#  [0.0744 0.1928]
# B_hl
#  [ 0.1727  0.1759 -0.2334]
# A_op
#  [[0.3295 0.743 ]
#  [0.388  0.8912]
#  [0.3417 0.8586]
#  [0.4007 0.9867]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4152973199181091
#
#
# 	 Training... Epoch 17
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3295 0.743 ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2558 0.5936]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5349 0.7458]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8353 0.9908]]
# [[0 1]]
# W_op
#  [[ 0.3007  0.2145]
#  [-0.0408  0.4033]
#  [ 0.2471  0.5111]]
# W_hl
#  [[0.0056 0.9001 0.2921]
#  [0.3819 0.6281 0.5728]]
# B_op
#  [0.0833 0.1782]
# B_hl
#  [ 0.1667  0.1676 -0.24  ]
# A_op
#  [[0.3328 0.7379]
#  [0.3897 0.8898]
#  [0.343  0.857 ]
#  [0.4008 0.9881]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.41320171783676285
#
#
# 	 Training... Epoch 18
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3328 0.7379]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2567 0.5949]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5339 0.7458]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8326 0.9937]]
# [[0 1]]
# W_op
#  [[ 0.3022  0.2141]
#  [-0.0464  0.4177]
#  [ 0.2415  0.5197]]
# W_hl
#  [[3.000e-04 9.017e-01 2.916e-01]
#  [3.780e-01 6.281e-01 5.756e-01]]
# B_op
#  [0.0921 0.1637]
# B_hl
#  [ 0.1607  0.1592 -0.2466]
# A_op
#  [[0.3361 0.7328]
#  [0.3914 0.8883]
#  [0.3443 0.8554]
#  [0.4008 0.9896]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.41112412828836997
#
#
# 	 Training... Epoch 19
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3361 0.7328]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2575 0.5962]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.533  0.7459]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.83   0.9967]]
# [[0 1]]
# W_op
#  [[ 0.3036  0.2136]
#  [-0.052   0.4321]
#  [ 0.2359  0.5283]]
# W_hl
#  [[-0.0051  0.9034  0.2913]
#  [ 0.3741  0.6285  0.5785]]
# B_op
#  [0.1007 0.1494]
# B_hl
#  [ 0.1547  0.1508 -0.2532]
# A_op
#  [[0.3394 0.7276]
#  [0.3931 0.8868]
#  [0.3455 0.8538]
#  [0.4008 0.991 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4090632997936548
#
#
# 	 Training... Epoch 20
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3394 0.7276]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2584 0.5974]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5321 0.746 ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8273 0.9998]]
# [[0 1]]
# W_op
#  [[ 0.3051  0.213 ]
#  [-0.0577  0.4464]
#  [ 0.2304  0.5368]]
# W_hl
#  [[-0.0104  0.9054  0.2912]
#  [ 0.3702  0.6291  0.5816]]
# B_op
#  [0.1093 0.1352]
# B_hl
#  [ 0.1488  0.1423 -0.2599]
# A_op
#  [[0.3426 0.7224]
#  [0.3947 0.8852]
#  [0.3467 0.8522]
#  [0.4007 0.9925]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4070181636063524
#
#
# 	 Training... Epoch 21
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3426 0.7224]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2592 0.5986]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5311 0.7462]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8247 1.0029]]
# [[0 1]]
# W_op
#  [[ 0.3067  0.2122]
#  [-0.0633  0.4607]
#  [ 0.2248  0.5453]]
# W_hl
#  [[-0.0157  0.9075  0.2912]
#  [ 0.3663  0.6299  0.5848]]
# B_op
#  [0.1178 0.1212]
# B_hl
#  [ 0.143   0.1339 -0.2665]
# A_op
#  [[0.3458 0.7172]
#  [0.3963 0.8837]
#  [0.3479 0.8506]
#  [0.4006 0.994 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4049878286871975
#
#
# 	 Training... Epoch 22
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3458 0.7172]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.26   0.5999]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5302 0.7463]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8222 1.0061]]
# [[0 1]]
# W_op
#  [[ 0.3083  0.2114]
#  [-0.0689  0.4749]
#  [ 0.2193  0.5538]]
# W_hl
#  [[-0.021   0.9099  0.2914]
#  [ 0.3624  0.6309  0.5881]]
# B_op
#  [0.1261 0.1073]
# B_hl
#  [ 0.1372  0.1254 -0.273 ]
# A_op
#  [[0.349  0.7119]
#  [0.3979 0.8822]
#  [0.3491 0.849 ]
#  [0.4005 0.9956]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.40297157652400944
#
#
# 	 Training... Epoch 23
# Passing samples in the range of 0 : 1
# A_op
#  [[0.349  0.7119]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2608 0.6011]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5294 0.7465]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8196 1.0093]]
# [[0 1]]
# W_op
#  [[ 0.31    0.2104]
#  [-0.0745  0.489 ]
#  [ 0.2138  0.5623]]
# W_hl
#  [[-0.0263  0.9124  0.2918]
#  [ 0.3585  0.6321  0.5915]]
# B_op
#  [0.1344 0.0936]
# B_hl
#  [ 0.1315  0.1169 -0.2796]
# A_op
#  [[0.3522 0.7065]
#  [0.3995 0.8807]
#  [0.3502 0.8474]
#  [0.4003 0.9972]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.4009688557491865
#
#
# 	 Training... Epoch 24
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3522 0.7065]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2615 0.6023]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5285 0.7466]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8171 1.0126]]
# [[0 1]]
# W_op
#  [[ 0.3117  0.2093]
#  [-0.0801  0.5031]
#  [ 0.2083  0.5707]]
# W_hl
#  [[-0.0316  0.9151  0.2923]
#  [ 0.3547  0.6336  0.595 ]]
# B_op
#  [0.1425 0.08  ]
# B_hl
#  [ 0.1258  0.1084 -0.2862]
# A_op
#  [[0.3553 0.7011]
#  [0.401  0.8791]
#  [0.3513 0.8458]
#  [0.4001 0.9988]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.398979276510505
#
#
# 	 Training... Epoch 25
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3553 0.7011]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2623 0.6035]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5276 0.7468]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8145 1.0159]]
# [[0 1]]
# W_op
#  [[ 0.3135  0.2081]
#  [-0.0857  0.5171]
#  [ 0.2029  0.579 ]]
# W_hl
#  [[-0.0369  0.918   0.293 ]
#  [ 0.3508  0.6352  0.5987]]
# B_op
#  [0.1506 0.0665]
# B_hl
#  [ 0.1201  0.0999 -0.2928]
# A_op
#  [[0.3585 0.6957]
#  [0.4025 0.8776]
#  [0.3524 0.8443]
#  [0.3999 1.0005]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3970026045561975
#
#
# 	 Training... Epoch 26
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3585 0.6957]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.263  0.6047]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5268 0.7471]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.812  1.0192]]
# [[0 1]]
# W_op
#  [[ 0.3153  0.2068]
#  [-0.0912  0.531 ]
#  [ 0.1974  0.5874]]
# W_hl
#  [[-0.0422  0.921   0.2938]
#  [ 0.3469  0.637   0.6024]]
# B_op
#  [0.1585 0.0532]
# B_hl
#  [ 0.1145  0.0913 -0.2994]
# A_op
#  [[0.3616 0.6902]
#  [0.404  0.876 ]
#  [0.3534 0.8427]
#  [0.3996 1.0022]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.39503875500084995
#
#
# 	 Training... Epoch 27
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3616 0.6902]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2637 0.6059]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5259 0.7473]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8095 1.0226]]
# [[0 1]]
# W_op
#  [[ 0.3172  0.2054]
#  [-0.0967  0.5449]
#  [ 0.192   0.5957]]
# W_hl
#  [[-0.0475  0.9242  0.2948]
#  [ 0.3431  0.639   0.6062]]
# B_op
#  [0.1664 0.04  ]
# B_hl
#  [ 0.1089  0.0828 -0.3059]
# A_op
#  [[0.3647 0.6846]
#  [0.4054 0.8744]
#  [0.3545 0.8411]
#  [0.3993 1.0039]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.39308778574471004
#
#
# 	 Training... Epoch 28
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3647 0.6846]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2645 0.607 ]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5251 0.7476]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.807  1.0261]]
# [[0 1]]
# W_op
#  [[ 0.3191  0.2038]
#  [-0.1022  0.5588]
#  [ 0.1866  0.6039]]
# W_hl
#  [[-0.0528  0.9275  0.2958]
#  [ 0.3392  0.6411  0.6101]]
# B_op
#  [0.1741 0.0269]
# B_hl
#  [ 0.1034  0.0742 -0.3125]
# A_op
#  [[0.3678 0.679 ]
#  [0.4069 0.8729]
#  [0.3555 0.8395]
#  [0.399  1.0057]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3911498905254774
#
#
# 	 Training... Epoch 29
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3678 0.679 ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2652 0.6082]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5243 0.7478]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.8045 1.0296]]
# [[0 1]]
# W_op
#  [[ 0.3211  0.2022]
#  [-0.1077  0.5725]
#  [ 0.1812  0.6121]]
# W_hl
#  [[-0.0581  0.931   0.297 ]
#  [ 0.3353  0.6435  0.6141]]
# B_op
#  [0.1818 0.014 ]
# B_hl
#  [ 0.098   0.0656 -0.3191]
# A_op
#  [[0.3709 0.6734]
#  [0.4083 0.8713]
#  [0.3565 0.838 ]
#  [0.3986 1.0075]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.38922539158854663
#
#
# 	 Training... Epoch 30
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3709 0.6734]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2658 0.6093]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5235 0.7481]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.802  1.0331]]
# [[0 1]]
# W_op
#  [[ 0.3231  0.2005]
#  [-0.1131  0.5862]
#  [ 0.1758  0.6203]]
# W_hl
#  [[-0.0634  0.9346  0.2983]
#  [ 0.3315  0.6459  0.6182]]
# B_op
#  [0.1894 0.0012]
# B_hl
#  [ 0.0926  0.0571 -0.3256]
# A_op
#  [[0.374  0.6676]
#  [0.4097 0.8697]
#  [0.3575 0.8364]
#  [0.3982 1.0093]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3873147319689004
#
#
# 	 Training... Epoch 31
# Passing samples in the range of 0 : 1
# A_op
#  [[0.374  0.6676]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2665 0.6105]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5227 0.7484]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7995 1.0367]]
# [[0 1]]
# W_op
#  [[ 0.3252  0.1986]
#  [-0.1185  0.5998]
#  [ 0.1705  0.6284]]
# W_hl
#  [[-0.0687  0.9383  0.2997]
#  [ 0.3276  0.6485  0.6223]]
# B_op
#  [ 0.1968 -0.0114]
# B_hl
#  [ 0.0872  0.0485 -0.3321]
# A_op
#  [[0.377  0.6619]
#  [0.4111 0.868 ]
#  [0.3585 0.8348]
#  [0.3978 1.0111]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3854184673853635
#
#
# 	 Training... Epoch 32
# Passing samples in the range of 0 : 1
# A_op
#  [[0.377  0.6619]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2672 0.6116]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5219 0.7487]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.797  1.0403]]
# [[0 1]]
# W_op
#  [[ 0.3274  0.1967]
#  [-0.1239  0.6133]
#  [ 0.1651  0.6365]]
# W_hl
#  [[-0.074   0.9421  0.3012]
#  [ 0.3237  0.6512  0.6264]]
# B_op
#  [ 0.2042 -0.0239]
# B_hl
#  [ 0.0819  0.0399 -0.3387]
# A_op
#  [[0.3801 0.6561]
#  [0.4125 0.8664]
#  [0.3594 0.8333]
#  [0.3973 1.013 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.38353725775561487
#
#
# 	 Training... Epoch 33
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3801 0.6561]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2678 0.6127]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5211 0.7491]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7945 1.0439]]
# [[0 1]]
# W_op
#  [[ 0.3295  0.1946]
#  [-0.1292  0.6267]
#  [ 0.1598  0.6445]]
# W_hl
#  [[-0.0793  0.946   0.3028]
#  [ 0.3198  0.6541  0.6307]]
# B_op
#  [ 0.2115 -0.0363]
# B_hl
#  [ 0.0766  0.0313 -0.3452]
# A_op
#  [[0.3832 0.6502]
#  [0.4138 0.8648]
#  [0.3604 0.8317]
#  [0.3969 1.0149]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3816718583481481
#
#
# 	 Training... Epoch 34
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3832 0.6502]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2685 0.6139]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5203 0.7494]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.792  1.0476]]
# [[0 1]]
# W_op
#  [[ 0.3318  0.1925]
#  [-0.1344  0.64  ]
#  [ 0.1545  0.6525]]
# W_hl
#  [[-0.0847  0.95    0.3044]
#  [ 0.3158  0.6571  0.6349]]
# B_op
#  [ 0.2187 -0.0485]
# B_hl
#  [ 0.0714  0.0227 -0.3517]
# A_op
#  [[0.3863 0.6443]
#  [0.4152 0.8631]
#  [0.3613 0.8301]
#  [0.3964 1.0168]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.379823110595133
#
#
# 	 Training... Epoch 35
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3863 0.6443]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2691 0.615 ]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5196 0.7497]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7896 1.0514]]
# [[0 1]]
# W_op
#  [[ 0.334   0.1903]
#  [-0.1396  0.6533]
#  [ 0.1492  0.6604]]
# W_hl
#  [[-0.09    0.9541  0.3062]
#  [ 0.3119  0.6601  0.6392]]
# B_op
#  [ 0.2258 -0.0606]
# B_hl
#  [ 0.0663  0.0141 -0.3581]
# A_op
#  [[0.3894 0.6384]
#  [0.4165 0.8614]
#  [0.3623 0.8286]
#  [0.3959 1.0188]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.37799193259776775
#
#
# 	 Training... Epoch 36
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3894 0.6384]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2697 0.6161]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5188 0.7501]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7871 1.0551]]
# [[0 1]]
# W_op
#  [[ 0.3364  0.188 ]
#  [-0.1448  0.6665]
#  [ 0.1439  0.6683]]
# W_hl
#  [[-0.0954  0.9582  0.3079]
#  [ 0.3079  0.6633  0.6435]]
# B_op
#  [ 0.2328 -0.0725]
# B_hl
#  [ 0.0611  0.0055 -0.3646]
# A_op
#  [[0.3925 0.6324]
#  [0.4178 0.8598]
#  [0.3632 0.827 ]
#  [0.3953 1.0207]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3761793093630903
#
#
# 	 Training... Epoch 37
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3925 0.6324]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2703 0.6172]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5181 0.7505]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7846 1.0589]]
# [[0 1]]
# W_op
#  [[ 0.3387  0.1856]
#  [-0.1499  0.6795]
#  [ 0.1387  0.6761]]
# W_hl
#  [[-0.1008  0.9625  0.3098]
#  [ 0.304   0.6665  0.6479]]
# B_op
#  [ 0.2397 -0.0843]
# B_hl
#  [ 0.0561 -0.0031 -0.371 ]
# A_op
#  [[0.3956 0.6264]
#  [0.4192 0.8581]
#  [0.3641 0.8254]
#  [0.3947 1.0227]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.37438628281820874
#
#
# 	 Training... Epoch 38
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3956 0.6264]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2709 0.6182]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5174 0.7509]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7821 1.0627]]
# [[0 1]]
# W_op
#  [[ 0.3411  0.1832]
#  [-0.1549  0.6925]
#  [ 0.1335  0.6838]]
# W_hl
#  [[-0.1062  0.9667  0.3117]
#  [ 0.3     0.6698  0.6523]]
# B_op
#  [ 0.2465 -0.0959]
# B_hl
#  [ 0.051  -0.0117 -0.3775]
# A_op
#  [[0.3987 0.6203]
#  [0.4205 0.8564]
#  [0.365  0.8238]
#  [0.3942 1.0247]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3726139416543919
#
#
# 	 Training... Epoch 39
# Passing samples in the range of 0 : 1
# A_op
#  [[0.3987 0.6203]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2715 0.6193]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5166 0.7512]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7796 1.0666]]
# [[0 1]]
# W_op
#  [[ 0.3436  0.1806]
#  [-0.1599  0.7053]
#  [ 0.1283  0.6915]]
# W_hl
#  [[-0.1117  0.971   0.3137]
#  [ 0.296   0.6732  0.6567]]
# B_op
#  [ 0.2532 -0.1074]
# B_hl
#  [ 0.0461 -0.0202 -0.3839]
# A_op
#  [[0.4018 0.6142]
#  [0.4218 0.8547]
#  [0.3659 0.8223]
#  [0.3936 1.0268]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3708634110593012
#
#
# 	 Training... Epoch 40
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4018 0.6142]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2721 0.6204]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5159 0.7516]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7771 1.0705]]
# [[0 1]]
# W_op
#  [[ 0.3461  0.178 ]
#  [-0.1648  0.7181]
#  [ 0.1231  0.6991]]
# W_hl
#  [[-0.1171  0.9754  0.3156]
#  [ 0.292   0.6767  0.661 ]]
# B_op
#  [ 0.2598 -0.1188]
# B_hl
#  [ 0.0411 -0.0288 -0.3903]
# A_op
#  [[0.4049 0.6081]
#  [0.4231 0.853 ]
#  [0.3668 0.8207]
#  [0.3929 1.0288]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3691358424007246
#
#
# 	 Training... Epoch 41
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4049 0.6081]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2727 0.6214]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5152 0.752 ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7747 1.0744]]
# [[0 1]]
# W_op
#  [[ 0.3486  0.1753]
#  [-0.1696  0.7307]
#  [ 0.118   0.7067]]
# W_hl
#  [[-0.1226  0.9797  0.3177]
#  [ 0.288   0.6802  0.6654]]
# B_op
#  [ 0.2663 -0.13  ]
# B_hl
#  [ 0.0362 -0.0373 -0.3966]
# A_op
#  [[0.408  0.602 ]
#  [0.4243 0.8512]
#  [0.3677 0.8191]
#  [0.3923 1.0309]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3674324029293794
#
#
# 	 Training... Epoch 42
# Passing samples in the range of 0 : 1
# A_op
#  [[0.408 0.602]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2733 0.6225]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5145 0.7524]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7722 1.0783]]
# [[0 1]]
# W_op
#  [[ 0.3512  0.1726]
#  [-0.1744  0.7433]
#  [ 0.1129  0.7141]]
# W_hl
#  [[-0.1281  0.9841  0.3197]
#  [ 0.284   0.6837  0.6698]]
# B_op
#  [ 0.2727 -0.141 ]
# B_hl
#  [ 0.0314 -0.0458 -0.403 ]
# A_op
#  [[0.4111 0.5958]
#  [0.4256 0.8495]
#  [0.3686 0.8176]
#  [0.3916 1.0329]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3657542655715835
#
#
# 	 Training... Epoch 43
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4111 0.5958]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2739 0.6235]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5138 0.7529]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7697 1.0822]]
# [[0 1]]
# W_op
#  [[ 0.3538  0.1698]
#  [-0.1791  0.7557]
#  [ 0.1078  0.7215]]
# W_hl
#  [[-0.1336  0.9885  0.3218]
#  [ 0.2799  0.6873  0.6742]]
# B_op
#  [ 0.279  -0.1519]
# B_hl
#  [ 0.0266 -0.0543 -0.4093]
# A_op
#  [[0.4142 0.5897]
#  [0.4269 0.8478]
#  [0.3695 0.816 ]
#  [0.391  1.035 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3641025988847698
#
#
# 	 Training... Epoch 44
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4142 0.5897]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2744 0.6245]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5131 0.7533]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7672 1.0861]]
# [[0 1]]
# W_op
#  [[ 0.3565  0.167 ]
#  [-0.1837  0.768 ]
#  [ 0.1028  0.7288]]
# W_hl
#  [[-0.1391  0.9929  0.3238]
#  [ 0.2758  0.6909  0.6785]]
# B_op
#  [ 0.2852 -0.1626]
# B_hl
#  [ 0.0218 -0.0628 -0.4156]
# A_op
#  [[0.4173 0.5835]
#  [0.4282 0.846 ]
#  [0.3704 0.8144]
#  [0.3903 1.0371]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.362478557249867
#
#
# 	 Training... Epoch 45
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4173 0.5835]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.275  0.6255]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5124 0.7537]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7647 1.0901]]
# [[0 1]]
# W_op
#  [[ 0.3592  0.1641]
#  [-0.1882  0.7802]
#  [ 0.0978  0.7361]]
# W_hl
#  [[-0.1446  0.9973  0.3259]
#  [ 0.2718  0.6945  0.6829]]
# B_op
#  [ 0.2913 -0.1732]
# B_hl
#  [ 0.0171 -0.0712 -0.4218]
# A_op
#  [[0.4205 0.5773]
#  [0.4294 0.8443]
#  [0.3712 0.8129]
#  [0.3896 1.0392]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3608832713744541
#
#
# 	 Training... Epoch 46
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4205 0.5773]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2755 0.6265]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5118 0.7541]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7622 1.094 ]]
# [[0 1]]
# W_op
#  [[ 0.3619  0.1611]
#  [-0.1927  0.7922]
#  [ 0.0928  0.7432]]
# W_hl
#  [[-0.1502  1.0017  0.328 ]
#  [ 0.2677  0.6981  0.6872]]
# B_op
#  [ 0.2974 -0.1835]
# B_hl
#  [ 0.0125 -0.0797 -0.4281]
# A_op
#  [[0.4236 0.5711]
#  [0.4307 0.8426]
#  [0.3721 0.8113]
#  [0.3889 1.0413]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.35931783917928145
#
#
# 	 Training... Epoch 47
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4236 0.5711]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2761 0.6274]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5111 0.7545]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7597 1.098 ]]
# [[0 1]]
# W_op
#  [[ 0.3647  0.1582]
#  [-0.197   0.8041]
#  [ 0.0879  0.7503]]
# W_hl
#  [[-0.1557  1.006   0.3301]
#  [ 0.2636  0.7018  0.6915]]
# B_op
#  [ 0.3033 -0.1938]
# B_hl
#  [ 0.0078 -0.088  -0.4343]
# A_op
#  [[0.4267 0.5649]
#  [0.4319 0.8408]
#  [0.373  0.8097]
#  [0.3882 1.0434]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3577833171382516
#
#
# 	 Training... Epoch 48
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4267 0.5649]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2766 0.6284]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5104 0.7549]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7572 1.102 ]]
# [[0 1]]
# W_op
#  [[ 0.3674  0.1552]
#  [-0.2013  0.8159]
#  [ 0.083   0.7573]]
# W_hl
#  [[-0.1613  1.0103  0.3321]
#  [ 0.2595  0.7054  0.6957]]
# B_op
#  [ 0.3091 -0.2038]
# B_hl
#  [ 0.0033 -0.0964 -0.4404]
# A_op
#  [[0.4298 0.5588]
#  [0.4332 0.839 ]
#  [0.3739 0.8082]
#  [0.3874 1.0455]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.35628071213828694
#
#
# 	 Training... Epoch 49
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4298 0.5588]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2772 0.6293]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5098 0.7554]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7547 1.1059]]
# [[0 1]]
# W_op
#  [[ 0.3702  0.1521]
#  [-0.2055  0.8275]
#  [ 0.0781  0.7641]]
# W_hl
#  [[-0.1669  1.0146  0.3342]
#  [ 0.2554  0.709   0.6999]]
# B_op
#  [ 0.3148 -0.2137]
# B_hl
#  [-0.0013 -0.1047 -0.4466]
# A_op
#  [[0.4329 0.5526]
#  [0.4344 0.8373]
#  [0.3748 0.8066]
#  [0.3867 1.0476]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3548109739207417
#
#
# 	 Training... Epoch 50
# Passing samples in the range of 0 : 1
# A_op
#  [[0.4329 0.5526]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[0.2777 0.6303]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[0.5091 0.7558]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[0.7522 1.1099]]
# [[0 1]]
# W_op
#  [[ 0.3731  0.1491]
#  [-0.2096  0.839 ]
#  [ 0.0733  0.7709]]
# W_hl
#  [[-0.1725  1.0189  0.3362]
#  [ 0.2512  0.7126  0.704 ]]
# B_op
#  [ 0.3204 -0.2234]
# B_hl
#  [-0.0058 -0.113  -0.4527]
# A_op
#  [[0.436  0.5464]
#  [0.4357 0.8355]
#  [0.3756 0.8051]
#  [0.386  1.0497]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3533749881602031
#
#
#
#
# Done! Final prediction result:
# A_op
#  [[0.436  0.5464]
#  [0.4357 0.8355]
#  [0.3756 0.8051]
#  [0.386  1.0497]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 0.3533749881602031

# %%
# Network 2
# Çıkışta sigmoid var
# Loss: Binary Cross Entropy
# bir gizli katmanımız ve bir çıktı katmanımız var
# gizli katman 3 nöronlu; yani her bir girdi nöronundan üçer bağlantı başlar

print("#"*50)
print("Network 2")
print("#"*50)

W_hl = rndarr(np.random.random((2, 3))) # gizli katmana giden ağırlıklar
B_hl = np.random.random((3)) # gizli katman için bias
Z_hl = np.zeros((3)) # gizli katman sonucu (inaktif)
A_hl = np.zeros((3)) # gizli katman sonucu
D_hl = np.random.random((2, 3)) # gizli katmana giden ağırlıklarının deltaları

W_op = rndarr(np.random.random((3, 2))) # çıktı katmanına giden ağırlıklar
B_op = np.random.random((2)) # çıktı katmanı için bias
Z_op = np.zeros((2)) # çıktı katmanı sonucu (inaktif)
A_op = np.zeros((2)) # çıktı katmanı sonucu
D_op = np.random.random((3, 2)) # çıktı katmanına giden ağırlıkların deltaları

####### DATA




print("Weights and biases before starting:")
prnt("W_op")
prnt("W_hl")
prnt("B_op")
prnt("B_hl")
print("\n\n")

for epoch in range(1,51):
    print("\t Training... Epoch",epoch)
    for bno in range(0,sample_count,batch_size):
        
        print("Passing samples in the range of",bno,":",bno+batch_size)
        i_low = bno
        i_high = bno+batch_size
        if i_high > sample_count:
            i_high = sample_count
        batch_x = dataset_x[i_low:i_high]
        batch_y = dataset_y[i_low:i_high]
        # print(batch_x,batch_y,"\n\n\n")
        
    
        prediction(batch_x, batch_y)

        # print("A_op",A_op)
        # error = (batch_y[i] - A_op)**2
        error = loss_function_bce(A_op, batch_y)
#         D_op = loss_function_bce_d(A_op, batch_y)
        D_op = derivative(loss_function_bce,A_op, batch_y)
        # prnt("D_op")
        # prnt("delta_by")
        # print("A_hl",A_hl)
        delta_wy = np.array([np.outer(D_op[a],A_hl[a]) for a in range(len(D_op))])
        delta_wy = np.average(delta_wy,axis=0).T
        # print("delta_wy",delta_wy)
        delta_by = np.average(D_op,axis=0).T


        D_hl = np.dot(D_op, W_op.T)
        D_hl = np.multiply(D_hl, sigmoid_d(A_hl))
        # print("D_hl",D_hl)
        delta_wh = np.array([np.outer(D_hl[a],batch_x[a]) for a in range(len(D_hl))])
        delta_wh = np.average(delta_wh,axis=0).T
        # print("delta_wh",delta_wh)
        delta_bh = np.average(D_hl,axis=0).T


        # print("W_op",W_op)
        # print("W_hl",W_hl)
        # error2 = loss_function_mse(A_op, batch_y[i])
        # delta_op = np.dot(batch_x, error * sigmoid_d(A_op))


        W_op -= learning_rate * delta_wy
        W_hl -= learning_rate * delta_wh


        B_op -= learning_rate * delta_by
        B_hl -= learning_rate * delta_bh

    
    prnt("W_op")
    prnt("W_hl")
    prnt("B_op")
    prnt("B_hl")
    prediction(dataset_x, dataset_y)
    print("Loss:",loss_function_mse(A_op,dataset_y))
    print("\n")


print("\n\nDone! Final prediction result:")
prediction(dataset_x, dataset_y)
print("Loss:",loss_function_mse(A_op,dataset_y))
# print(A_op)
# autodiff mse için çalışıyor fakat BCE'de loss değeri patlıyor
# Out:
# ##################################################
# Network 2
# ##################################################
# Weights and biases before starting:
# W_op
#  [[0.09 0.07]
#  [0.99 0.04]
#  [0.52 0.73]]
# W_hl
#  [[0.99 0.9  0.64]
#  [0.27 0.43 0.58]]
# B_op
#  [0.0329 0.013 ]
# B_hl
#  [0.0939 0.5769 0.0977]
#
#
#
# 	 Training... Epoch 1
# Passing samples in the range of 0 : 1
# A_op
#  [[0.9867 0.4581]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-2.2194 -2.7552]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[1.1164 0.5543]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[5.2283 4.5848]]
# [[0 1]]
# W_op
#  [[0.1955 2.1051]
#  [0.7663 2.4767]
#  [0.0873 2.9446]]
# W_hl
#  [[ 1.1029  0.9614  1.2152]
#  [-0.3046 -0.2697  0.4872]]
# B_op
#  [0.0329 3.2367]
# B_hl
#  [-0.4207 -0.1122  0.0377]
# A_op
#  [[0.5166 6.74  ]
#  [0.4624 6.7782]
#  [0.7674 8.66  ]
#  [0.7144 8.5781]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 49.009553712823376
#
#
# 	 Training... Epoch 2
# Passing samples in the range of 0 : 1
# A_op
#  [[0.5166 6.74  ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-1.9079  2.8939]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[-0.0195  7.0949]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[ 4.1833 13.281 ]]
# [[0 1]]
# W_op
#  [[-0.6005  3.9298]
#  [-0.2785  4.3864]
#  [-0.676   5.3109]]
# W_hl
#  [[2.3403 2.3615 3.0449]
#  [0.7599 0.9819 1.948 ]]
# B_op
#  [0.0329 6.4603]
# B_hl
#  [0.3345 0.7402 1.2648]
# A_op
#  [[-1.0328 15.8622]
#  [-1.3031 18.2314]
#  [-1.4624 19.5747]
#  [-1.4974 19.8818]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 316.1868787355859
#
#
# 	 Training... Epoch 3
# Passing samples in the range of 0 : 1
# A_op
#  [[-1.0328 15.8622]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-4.6719 11.4608]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[-1.6607 18.8072]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[ 4.242  25.8208]]
# [[0 1]]
# W_op
#  [[-0.9749  6.7626]
#  [-0.6056  7.278 ]
#  [-0.6421  8.5681]]
# W_hl
#  [[4.7645 5.0706 6.4868]
#  [2.7529 3.1792 4.5675]]
# B_op
#  [0.0329 9.6839]
# B_hl
#  [2.0789 2.688  3.8187]
# A_op
#  [[-2.029  30.8933]
#  [-2.1801 32.2167]
#  [-2.1884 32.282 ]
#  [-2.1896 32.292 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 978.9564088202146
#
#
# 	 Training... Epoch 4
# Passing samples in the range of 0 : 1
# A_op
#  [[-2.029  30.8933]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-8.1378 25.7249]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[-1.9975 32.4529]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[ 4.4399 38.9223]]
# [[0 1]]
# W_op
#  [[-0.8839 10.0773]
#  [-0.5441 10.5632]
#  [-0.6123 11.8215]]
# W_hl
#  [[ 9.1137  9.7247 11.9364]
#  [ 6.153   6.8484  9.0004]]
# B_op
#  [ 0.0329 12.9075]
# B_hl
#  [5.4502 6.3373 8.2459]
# A_op
#  [[-2.0024 45.3047]
#  [-2.0073 45.3694]
#  [-2.0073 45.3695]
#  [-2.0073 45.3695]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 1996.147817344553
#
#
# 	 Training... Epoch 5
# Passing samples in the range of 0 : 1
# A_op
#  [[-2.0024 45.3047]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-8.4438 38.9306]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[-1.9975 45.3793]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[ 4.4498 51.8266]]
# [[0 1]]
# W_op
#  [[-0.8773 13.3075]
#  [-0.5413 13.7896]
#  [-0.6118 15.0456]]
# W_hl
#  [[15.5049 16.4215 19.4292]
#  [11.523  12.5237 15.4716]]
# B_op
#  [ 0.0329 16.1311]
# B_hl
#  [10.8186 12.0117 14.7169]
# A_op
#  [[-1.9975 58.2735]
#  [-1.9975 58.2738]
#  [-1.9975 58.2738]
#  [-1.9975 58.2738]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 3315.6532135244825
#
#
# 	 Training... Epoch 6
# Passing samples in the range of 0 : 1
# A_op
#  [[-1.9975 58.2735]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-8.4447 51.8266]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[-1.9974 58.2739]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[ 4.4498 64.7211]]
# [[0 1]]
# W_op
#  [[-0.8772 16.5312]
#  [-0.5413 17.0132]
#  [-0.6118 18.2692]]
# W_hl
#  [[23.9393 25.1614 28.9651]
#  [18.9357 20.242  23.9859]]
# B_op
#  [ 0.0329 19.3547]
# B_hl
#  [18.2313 19.73   23.2313]
# A_op
#  [[-1.9974 71.1683]
#  [-1.9974 71.1683]
#  [-1.9974 71.1683]
#  [-1.9974 71.1683]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 4965.41577509112
#
#
# 	 Training... Epoch 7
# Passing samples in the range of 0 : 1
# A_op
#  [[-1.9974 71.1683]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-8.4447 64.7211]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[-1.9974 71.1683]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[ 4.4498 77.6156]]
# [[0 1]]
# W_op
#  [[-0.8772 19.7548]
#  [-0.5413 20.2368]
#  [-0.6118 21.4928]]
# W_hl
#  [[34.4168 35.9444 40.5442]
#  [28.3917 30.0035 34.5434]]
# B_op
#  [ 0.0329 22.5784]
# B_hl
#  [27.6873 29.4915 33.7887]
# A_op
#  [[-1.9974 84.0628]
#  [-1.9974 84.0628]
#  [-1.9974 84.0628]
#  [-1.9974 84.0628]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 6947.698307307515
#
#
# 	 Training... Epoch 8
# Passing samples in the range of 0 : 1
# A_op
#  [[-1.9974 84.0628]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-8.4447 77.6156]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[-1.9974 84.0628]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[ 4.4498 90.51  ]]
# [[0 1]]
# W_op
#  [[-0.8772 22.9784]
#  [-0.5413 23.4605]
#  [-0.6118 24.7164]]
# W_hl
#  [[46.9374 48.7705 54.1663]
#  [39.8907 41.8081 47.144 ]]
# B_op
#  [ 0.0329 25.802 ]
# B_hl
#  [39.1863 41.296  46.3894]
# A_op
#  [[-1.9974 96.9573]
#  [-1.9974 96.9573]
#  [-1.9974 96.9573]
#  [-1.9974 96.9573]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 9262.515882045345
#
#
# 	 Training... Epoch 9
# Passing samples in the range of 0 : 1
# A_op
#  [[-1.9974 96.9573]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[-8.4447 90.51  ]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[-1.9974 96.9573]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 103.4045]]
# [[0 1]]
# W_op
#  [[-0.8772 26.202 ]
#  [-0.5413 26.6841]
#  [-0.6118 27.94  ]]
# W_hl
#  [[61.5012 63.6398 69.8317]
#  [53.4329 55.6558 61.7878]]
# B_op
#  [ 0.0329 29.0256]
# B_hl
#  [52.7285 55.1438 61.0331]
# A_op
#  [[ -1.9974 109.8518]
#  [ -1.9974 109.8518]
#  [ -1.9974 109.8518]
#  [ -1.9974 109.8518]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 11909.868508110432
#
#
# 	 Training... Epoch 10
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 109.8518]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 103.4045]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 109.8518]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 116.299 ]]
# [[0 1]]
# W_op
#  [[-0.8772 29.4256]
#  [-0.5413 29.9077]
#  [-0.6118 31.1637]]
# W_hl
#  [[78.108  80.5523 87.5401]
#  [69.0182 71.5466 78.4747]]
# B_op
#  [ 0.0329 32.2492]
# B_hl
#  [68.3138 71.0346 77.72  ]
# A_op
#  [[ -1.9974 122.7462]
#  [ -1.9974 122.7462]
#  [ -1.9974 122.7462]
#  [ -1.9974 122.7462]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 14889.756189230015
#
#
# 	 Training... Epoch 11
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 122.7462]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 116.299 ]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 122.7462]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 129.1935]]
# [[0 1]]
# W_op
#  [[-0.8772 32.6493]
#  [-0.5413 33.1313]
#  [-0.6118 34.3873]]
# W_hl
#  [[ 96.7581  99.5078 107.2917]
#  [ 86.6467  89.4806  97.2047]]
# B_op
#  [3.29000e-02 3.54728e+01]
# B_hl
#  [85.9423 88.9686 96.45  ]
# A_op
#  [[ -1.9974 135.6407]
#  [ -1.9974 135.6407]
#  [ -1.9974 135.6407]
#  [ -1.9974 135.6407]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 18202.178923651263
#
#
# 	 Training... Epoch 12
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 135.6407]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 129.1935]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 135.6407]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 142.088 ]]
# [[0 1]]
# W_op
#  [[-0.8772 35.8729]
#  [-0.5413 36.3549]
#  [-0.6118 37.6109]]
# W_hl
#  [[117.4512 120.5065 129.0864]
#  [106.3183 109.4578 117.9779]]
# B_op
#  [3.29000e-02 3.86965e+01]
# B_hl
#  [105.6139 108.9457 117.2232]
# A_op
#  [[ -1.9974 148.5352]
#  [ -1.9974 148.5352]
#  [ -1.9974 148.5352]
#  [ -1.9974 148.5352]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 21847.136714068038
#
#
# 	 Training... Epoch 13
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 148.5352]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 142.088 ]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 148.5352]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 154.9824]]
# [[0 1]]
# W_op
#  [[-0.8772 39.0965]
#  [-0.5413 39.5786]
#  [-0.6118 40.8345]]
# W_hl
#  [[140.1875 143.5483 152.9243]
#  [128.033  131.478  140.7942]]
# B_op
#  [3.29000e-02 4.19201e+01]
# B_hl
#  [127.3286 130.966  140.0395]
# A_op
#  [[ -1.9974 161.4297]
#  [ -1.9974 161.4297]
#  [ -1.9974 161.4297]
#  [ -1.9974 161.4297]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 25824.629558258406
#
#
# 	 Training... Epoch 14
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 161.4297]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 154.9824]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 161.4297]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 167.8769]]
# [[0 1]]
# W_op
#  [[-0.8772 42.3201]
#  [-0.5413 42.8022]
#  [-0.6118 44.0581]]
# W_hl
#  [[164.967  168.6333 178.8053]
#  [151.7909 155.5414 165.6536]]
# B_op
#  [3.29000e-02 4.51437e+01]
# B_hl
#  [151.0865 155.0294 164.8989]
# A_op
#  [[ -1.9974 174.3241]
#  [ -1.9974 174.3241]
#  [ -1.9974 174.3241]
#  [ -1.9974 174.3241]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 30134.65746252844
#
#
# 	 Training... Epoch 15
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 174.3241]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 167.8769]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 174.3241]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 180.7714]]
# [[0 1]]
# W_op
#  [[-0.8772 45.5437]
#  [-0.5413 46.0258]
#  [-0.6118 47.2818]]
# W_hl
#  [[191.7896 195.7614 206.7295]
#  [177.5919 181.648  192.5562]]
# B_op
#  [3.29000e-02 4.83673e+01]
# B_hl
#  [176.8875 181.136  191.8015]
# A_op
#  [[ -1.9974 187.2186]
#  [ -1.9974 187.2186]
#  [ -1.9974 187.2186]
#  [ -1.9974 187.2186]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 34777.22042151737
#
#
# 	 Training... Epoch 16
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 187.2186]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 180.7714]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 187.2186]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 193.6659]]
# [[0 1]]
# W_op
#  [[-0.8772 48.7674]
#  [-0.5413 49.2494]
#  [-0.6118 50.5054]]
# W_hl
#  [[220.6553 224.9327 236.6967]
#  [205.436  209.7976 221.5019]]
# B_op
#  [3.29000e-02 5.15909e+01]
# B_hl
#  [204.7316 209.2856 220.7472]
# A_op
#  [[ -1.9974 200.1131]
#  [ -1.9974 200.1131]
#  [ -1.9974 200.1131]
#  [ -1.9974 200.1131]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 39752.31842796813
#
#
# 	 Training... Epoch 17
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 200.1131]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 193.6659]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 200.1131]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 206.5603]]
# [[0 1]]
# W_op
#  [[-0.8772 51.991 ]
#  [-0.5413 52.473 ]
#  [-0.6118 53.729 ]]
# W_hl
#  [[251.5641 256.147  268.7071]
#  [235.3233 239.9904 252.4907]]
# B_op
#  [3.29000e-02 5.48146e+01]
# B_hl
#  [234.6189 239.4784 251.7361]
# A_op
#  [[ -1.9974 213.0076]
#  [ -1.9974 213.0076]
#  [ -1.9974 213.0076]
#  [ -1.9974 213.0076]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 45059.951495914385
#
#
# 	 Training... Epoch 18
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 213.0076]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 206.5603]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 213.0076]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 219.4548]]
# [[0 1]]
# W_op
#  [[-0.8772 55.2146]
#  [-0.5413 55.6967]
#  [-0.6118 56.9526]]
# W_hl
#  [[284.5161 289.4046 302.7607]
#  [267.2537 272.2264 285.5227]]
# B_op
#  [3.29000e-02 5.80382e+01]
# B_hl
#  [266.5493 271.7144 284.768 ]
# A_op
#  [[ -1.9974 225.902 ]
#  [ -1.9974 225.902 ]
#  [ -1.9974 225.902 ]
#  [ -1.9974 225.902 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 50700.119618572426
#
#
# 	 Training... Epoch 19
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 225.902 ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 219.4548]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 225.902 ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 232.3493]]
# [[0 1]]
# W_op
#  [[-0.8772 58.4382]
#  [-0.5413 58.9203]
#  [-0.6118 60.1762]]
# W_hl
#  [[319.5112 324.7052 338.8574]
#  [301.2273 306.5055 320.5978]]
# B_op
#  [3.29000e-02 6.12618e+01]
# B_hl
#  [300.5229 305.9935 319.8431]
# A_op
#  [[ -1.9974 238.7965]
#  [ -1.9974 238.7965]
#  [ -1.9974 238.7965]
#  [ -1.9974 238.7965]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 56672.82279594225
#
#
# 	 Training... Epoch 20
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 238.7965]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 232.3493]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 238.7965]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 245.2438]]
# [[0 1]]
# W_op
#  [[-0.8772 61.6618]
#  [-0.5413 62.1439]
#  [-0.6118 63.3999]]
# W_hl
#  [[356.5495 362.049  376.9972]
#  [337.244  342.8277 357.7161]]
# B_op
#  [3.29000e-02 6.44854e+01]
# B_hl
#  [336.5396 342.3157 356.9614]
# A_op
#  [[ -1.9974 251.691 ]
#  [ -1.9974 251.691 ]
#  [ -1.9974 251.691 ]
#  [ -1.9974 251.691 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 62978.061018891865
#
#
# 	 Training... Epoch 21
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 251.691 ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 245.2438]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 251.691 ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 258.1382]]
# [[0 1]]
# W_op
#  [[-0.8772 64.8855]
#  [-0.5413 65.3675]
#  [-0.6118 66.6235]]
# W_hl
#  [[395.6309 401.4359 417.1802]
#  [375.3038 381.1931 396.8775]]
# B_op
#  [3.2900e-02 6.7709e+01]
# B_hl
#  [374.5994 380.681  396.1228]
# A_op
#  [[ -1.9974 264.5855]
#  [ -1.9974 264.5855]
#  [ -1.9974 264.5855]
#  [ -1.9974 264.5855]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 69615.83430521334
#
#
# 	 Training... Epoch 22
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 264.5855]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 258.1382]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 264.5855]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 271.0327]]
# [[0 1]]
# W_op
#  [[-0.8772 68.1091]
#  [-0.5413 68.5911]
#  [-0.6118 69.8471]]
# W_hl
#  [[436.7554 442.866  459.4062]
#  [415.4068 421.6015 438.082 ]]
# B_op
#  [3.29000e-02 7.09327e+01]
# B_hl
#  [414.7023 421.0895 437.3273]
# A_op
#  [[ -1.9974 277.48  ]
#  [ -1.9974 277.48  ]
#  [ -1.9974 277.48  ]
#  [ -1.9974 277.48  ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 76586.14261604732
#
#
# 	 Training... Epoch 23
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 277.48  ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 271.0327]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 277.48  ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 283.9272]]
# [[0 1]]
# W_op
#  [[-0.8772 71.3327]
#  [-0.5413 71.8148]
#  [-0.6118 73.0707]]
# W_hl
#  [[479.9231 486.3392 503.6755]
#  [457.5529 464.0532 481.3296]]
# B_op
#  [3.29000e-02 7.41563e+01]
# B_hl
#  [456.8484 463.5412 480.575 ]
# A_op
#  [[ -1.9974 290.3744]
#  [ -1.9974 290.3744]
#  [ -1.9974 290.3744]
#  [ -1.9974 290.3744]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 83888.98595769702
#
#
# 	 Training... Epoch 24
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 290.3744]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 283.9272]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 290.3744]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 296.8217]]
# [[0 1]]
# W_op
#  [[-0.8772 74.5563]
#  [-0.5413 75.0384]
#  [-0.6118 76.2943]]
# W_hl
#  [[525.1339 531.8555 549.9878]
#  [501.7421 508.5479 526.6204]]
# B_op
#  [3.29000e-02 7.73799e+01]
# B_hl
#  [501.0377 508.0359 525.8658]
# A_op
#  [[ -1.9974 303.2689]
#  [ -1.9974 303.2689]
#  [ -1.9974 303.2689]
#  [ -1.9974 303.2689]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 91524.36441540666
#
#
# 	 Training... Epoch 25
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 303.2689]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 296.8217]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 303.2689]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 309.7161]]
# [[0 1]]
# W_op
#  [[-0.8772 77.7799]
#  [-0.5413 78.262 ]
#  [-0.6118 79.518 ]]
# W_hl
#  [[572.3878 579.415  598.3433]
#  [547.9745 555.0858 573.9544]]
# B_op
#  [3.29000e-02 8.06035e+01]
# B_hl
#  [547.27   554.5738 573.1997]
# A_op
#  [[ -1.9974 316.1634]
#  [ -1.9974 316.1634]
#  [ -1.9974 316.1634]
#  [ -1.9974 316.1634]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 99492.27788287043
#
#
# 	 Training... Epoch 26
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 316.1634]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 309.7161]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 316.1634]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 322.6106]]
# [[0 1]]
# W_op
#  [[-0.8772 81.0035]
#  [-0.5413 81.4856]
#  [-0.6118 82.7416]]
# W_hl
#  [[621.6849 629.0176 648.742 ]
#  [596.25   603.6669 623.3314]]
# B_op
#  [3.29000e-02 8.38271e+01]
# B_hl
#  [595.5455 603.1549 622.5768]
# A_op
#  [[ -1.9974 329.0579]
#  [ -1.9974 329.0579]
#  [ -1.9974 329.0579]
#  [ -1.9974 329.0579]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 107792.72642611896
#
#
# 	 Training... Epoch 27
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 329.0579]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 322.6106]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 329.0579]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 335.5051]]
# [[0 1]]
# W_op
#  [[-0.8772 84.2272]
#  [-0.5413 84.7092]
#  [-0.6118 85.9652]]
# W_hl
#  [[673.0251 680.6633 701.1838]
#  [646.5686 654.291  674.7516]]
# B_op
#  [3.29000e-02 8.70508e+01]
# B_hl
#  [645.8642 653.779  673.997 ]
# A_op
#  [[ -1.9974 341.9523]
#  [ -1.9974 341.9523]
#  [ -1.9974 341.9523]
#  [ -1.9974 341.9523]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 116425.70997348959
#
#
# 	 Training... Epoch 28
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 341.9523]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 335.5051]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 341.9523]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 348.3996]]
# [[0 1]]
# W_op
#  [[-0.8772 87.4508]
#  [-0.5413 87.9328]
#  [-0.6118 89.1888]]
# W_hl
#  [[726.4084 734.3522 755.6687]
#  [698.9304 706.9584 728.215 ]]
# B_op
#  [3.29000e-02 9.02744e+01]
# B_hl
#  [698.226  706.4463 727.4603]
# A_op
#  [[ -1.9974 354.8468]
#  [ -1.9974 354.8468]
#  [ -1.9974 354.8468]
#  [ -1.9974 354.8468]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 125391.2285451171
#
#
# 	 Training... Epoch 29
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 354.8468]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 348.3996]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 354.8468]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 361.2941]]
# [[0 1]]
# W_op
#  [[-0.8772 90.6744]
#  [-0.5413 91.1565]
#  [-0.6118 92.4124]]
# W_hl
#  [[781.8349 790.0842 812.1967]
#  [753.3353 761.6688 783.7215]]
# B_op
#  [3.2900e-02 9.3498e+01]
# B_hl
#  [752.6309 761.1568 782.9668]
# A_op
#  [[ -1.9974 367.7413]
#  [ -1.9974 367.7413]
#  [ -1.9974 367.7413]
#  [ -1.9974 367.7413]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 134689.2822182933
#
#
# 	 Training... Epoch 30
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 367.7413]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 361.2941]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 367.7413]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 374.1885]]
# [[0 1]]
# W_op
#  [[-0.8772 93.898 ]
#  [-0.5413 94.3801]
#  [-0.6118 95.636 ]]
# W_hl
#  [[839.3045 847.8594 870.7679]
#  [809.7833 818.4224 841.2711]]
# B_op
#  [3.29000e-02 9.67216e+01]
# B_hl
#  [809.0789 817.9104 840.5164]
# A_op
#  [[ -1.9974 380.6358]
#  [ -1.9974 380.6358]
#  [ -1.9974 380.6358]
#  [ -1.9974 380.6358]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 144319.87094336667
#
#
# 	 Training... Epoch 31
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 380.6358]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 374.1885]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 380.6358]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 387.083 ]]
# [[0 1]]
# W_op
#  [[-0.8772 97.1216]
#  [-0.5413 97.6037]
#  [-0.6118 98.8597]]
# W_hl
#  [[898.8173 907.6777 931.3822]
#  [868.2745 877.2191 900.8638]]
# B_op
#  [3.29000e-02 9.99452e+01]
# B_hl
#  [867.5701 876.7071 900.1092]
# A_op
#  [[ -1.9974 393.5302]
#  [ -1.9974 393.5302]
#  [ -1.9974 393.5302]
#  [ -1.9974 393.5302]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 154282.99472033442
#
#
# 	 Training... Epoch 32
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 393.5302]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 387.083 ]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 393.5302]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 399.9775]]
# [[0 1]]
# W_op
#  [[ -0.8772 100.3453]
#  [ -0.5413 100.8273]
#  [ -0.6118 102.0833]]
# W_hl
#  [[960.3732 969.5391 994.0397]
#  [928.8089 938.059  962.4997]]
# B_op
#  [3.290000e-02 1.031688e+02]
# B_hl
#  [928.1044 937.5469 961.7451]
# A_op
#  [[ -1.9974 406.4247]
#  [ -1.9974 406.4247]
#  [ -1.9974 406.4247]
#  [ -1.9974 406.4247]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 164578.6535787147
#
#
# 	 Training... Epoch 33
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 406.4247]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 399.9775]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 406.4247]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 412.872 ]]
# [[0 1]]
# W_op
#  [[ -0.8772 103.5689]
#  [ -0.5413 104.0509]
#  [ -0.6118 105.3069]]
# W_hl
#  [[1023.9722 1033.4436 1058.7403]
#  [ 991.3863 1000.9419 1026.1787]]
# B_op
#  [3.290000e-02 1.063925e+02]
# B_hl
#  [ 990.6819 1000.4299 1025.4241]
# A_op
#  [[ -1.9974 419.3192]
#  [ -1.9974 419.3192]
#  [ -1.9974 419.3192]
#  [ -1.9974 419.3192]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 175206.8474299516
#
#
# 	 Training... Epoch 34
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 419.3192]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 412.872 ]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 419.3192]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 425.7664]]
# [[0 1]]
# W_op
#  [[ -0.8772 106.7925]
#  [ -0.5413 107.2746]
#  [ -0.6118 108.5305]]
# W_hl
#  [[1089.6144 1099.3913 1125.484 ]
#  [1056.0069 1065.8681 1091.9009]]
# B_op
#  [3.290000e-02 1.096161e+02]
# B_hl
#  [1055.3025 1065.3561 1091.1462]
# A_op
#  [[ -1.9974 432.2137]
#  [ -1.9974 432.2137]
#  [ -1.9974 432.2137]
#  [ -1.9974 432.2137]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 186167.57629982615
#
#
# 	 Training... Epoch 35
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 432.2137]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 425.7664]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 432.2137]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 438.6609]]
# [[0 1]]
# W_op
#  [[ -0.8772 110.0161]
#  [ -0.5413 110.4982]
#  [ -0.6118 111.7541]]
# W_hl
#  [[1157.2997 1167.3822 1194.2708]
#  [1122.6706 1132.8373 1159.6662]]
# B_op
#  [3.290000e-02 1.128397e+02]
# B_hl
#  [1121.9662 1132.3253 1158.9115]
# A_op
#  [[ -1.9974 445.1082]
#  [ -1.9974 445.1082]
#  [ -1.9974 445.1082]
#  [ -1.9974 445.1082]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 197460.8402178451
#
#
# 	 Training... Epoch 36
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 445.1082]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 438.6609]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 445.1082]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 451.5554]]
# [[0 1]]
# W_op
#  [[ -0.8772 113.2397]
#  [ -0.5413 113.7218]
#  [ -0.6118 114.9778]]
# W_hl
#  [[1227.0281 1237.4161 1265.1008]
#  [1191.3775 1201.8497 1229.4746]]
# B_op
#  [3.290000e-02 1.160633e+02]
# B_hl
#  [1190.6731 1201.3377 1228.72  ]
# A_op
#  [[ -1.9974 458.0026]
#  [ -1.9974 458.0026]
#  [ -1.9974 458.0026]
#  [ -1.9974 458.0026]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 209086.6392505475
#
#
# 	 Training... Epoch 37
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 458.0026]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 451.5554]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 458.0026]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 464.4499]]
# [[0 1]]
# W_op
#  [[ -0.8772 116.4634]
#  [ -0.5413 116.9454]
#  [ -0.6118 118.2014]]
# W_hl
#  [[1298.7997 1309.4932 1337.974 ]
#  [1262.1275 1272.9053 1301.3262]]
# B_op
#  [3.290000e-02 1.192869e+02]
# B_hl
#  [1261.4231 1272.3933 1300.5715]
# A_op
#  [[ -1.9974 470.8971]
#  [ -1.9974 470.8971]
#  [ -1.9974 470.8971]
#  [ -1.9974 470.8971]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 221044.97333514428
#
#
# 	 Training... Epoch 38
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 470.8971]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 464.4499]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 470.8971]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 477.3443]]
# [[0 1]]
# W_op
#  [[ -0.8772 119.687 ]
#  [ -0.5413 120.169 ]
#  [ -0.6118 121.425 ]]
# W_hl
#  [[1372.6144 1383.6135 1412.8903]
#  [1334.9207 1346.0039 1375.2209]]
# B_op
#  [3.290000e-02 1.225106e+02]
# B_hl
#  [1334.2162 1345.4919 1374.4662]
# A_op
#  [[ -1.9974 483.7916]
#  [ -1.9974 483.7916]
#  [ -1.9974 483.7916]
#  [ -1.9974 483.7916]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 233335.8424364923
#
#
# 	 Training... Epoch 39
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 483.7916]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 477.3443]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 483.7916]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 490.2388]]
# [[0 1]]
# W_op
#  [[ -0.8772 122.9106]
#  [ -0.5413 123.3927]
#  [ -0.6118 124.6486]]
# W_hl
#  [[1448.4722 1459.7768 1489.8497]
#  [1409.7569 1421.1458 1451.1587]]
# B_op
#  [3.290000e-02 1.257342e+02]
# B_hl
#  [1409.0525 1420.6337 1450.4041]
# A_op
#  [[ -1.9974 496.6861]
#  [ -1.9974 496.6861]
#  [ -1.9974 496.6861]
#  [ -1.9974 496.6861]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 245959.24666002084
#
#
# 	 Training... Epoch 40
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 496.6861]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 490.2388]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 496.6861]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 503.1333]]
# [[0 1]]
# W_op
#  [[ -0.8772 126.1342]
#  [ -0.5413 126.6163]
#  [ -0.6118 127.8722]]
# W_hl
#  [[1526.3732 1537.9834 1568.8522]
#  [1486.6363 1498.3307 1529.1397]]
# B_op
#  [3.290000e-02 1.289578e+02]
# B_hl
#  [1485.9319 1497.8187 1528.3851]
# A_op
#  [[ -1.9974 509.5805]
#  [ -1.9974 509.5805]
#  [ -1.9974 509.5805]
#  [ -1.9974 509.5805]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 258915.18590031064
#
#
# 	 Training... Epoch 41
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 509.5805]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 503.1333]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 509.5805]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 516.0278]]
# [[0 1]]
# W_op
#  [[ -0.8772 129.3578]
#  [ -0.5413 129.8399]
#  [ -0.6118 131.0959]]
# W_hl
#  [[1606.3173 1618.233  1649.8979]
#  [1565.5589 1577.5588 1609.1638]]
# B_op
#  [3.290000e-02 1.321814e+02]
# B_hl
#  [1564.8545 1577.0468 1608.4092]
# A_op
#  [[ -1.9974 522.475 ]
#  [ -1.9974 522.475 ]
#  [ -1.9974 522.475 ]
#  [ -1.9974 522.475 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 272203.66023045813
#
#
# 	 Training... Epoch 42
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 522.475 ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 516.0278]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 522.475 ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 528.9222]]
# [[0 1]]
# W_op
#  [[ -0.8772 132.5815]
#  [ -0.5413 133.0635]
#  [ -0.6118 134.3195]]
# W_hl
#  [[1688.3046 1700.5258 1732.9867]
#  [1646.5246 1658.83   1691.2311]]
# B_op
#  [3.29000e-02 1.35405e+02]
# B_hl
#  [1645.8202 1658.318  1690.4764]
# A_op
#  [[ -1.9974 535.3695]
#  [ -1.9974 535.3695]
#  [ -1.9974 535.3695]
#  [ -1.9974 535.3695]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 285824.6696143764
#
#
# 	 Training... Epoch 43
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 535.3695]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 528.9222]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 535.3695]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 541.8167]]
# [[0 1]]
# W_op
#  [[ -0.8772 135.8051]
#  [ -0.5413 136.2871]
#  [ -0.6118 137.5431]]
# W_hl
#  [[1772.335  1784.8617 1818.1187]
#  [1729.5334 1742.1443 1775.3415]]
# B_op
#  [3.290000e-02 1.386287e+02]
# B_hl
#  [1728.829  1741.6323 1774.5868]
# A_op
#  [[ -1.9974 548.264 ]
#  [ -1.9974 548.264 ]
#  [ -1.9974 548.264 ]
#  [ -1.9974 548.264 ]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 299778.21397239727
#
#
# 	 Training... Epoch 44
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 548.264 ]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 541.8167]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 548.264 ]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 554.7112]]
# [[0 1]]
# W_op
#  [[ -0.8772 139.0287]
#  [ -0.5413 139.5108]
#  [ -0.6118 140.7667]]
# W_hl
#  [[1858.4085 1871.2408 1905.2937]
#  [1814.5853 1827.5018 1861.495 ]]
# B_op
#  [3.290000e-02 1.418523e+02]
# B_hl
#  [1813.8809 1826.9898 1860.7403]
# A_op
#  [[ -1.9974 561.1584]
#  [ -1.9974 561.1584]
#  [ -1.9974 561.1584]
#  [ -1.9974 561.1584]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 314064.2933804305
#
#
# 	 Training... Epoch 45
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 561.1584]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 554.7112]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 561.1584]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 567.6057]]
# [[0 1]]
# W_op
#  [[ -0.8772 142.2523]
#  [ -0.5413 142.7344]
#  [ -0.6118 143.9903]]
# W_hl
#  [[1946.5251 1959.663  1994.512 ]
#  [1901.6804 1914.9025 1949.6916]]
# B_op
#  [3.290000e-02 1.450759e+02]
# B_hl
#  [1900.976  1914.3905 1948.937 ]
# A_op
#  [[ -1.9974 574.0529]
#  [ -1.9974 574.0529]
#  [ -1.9974 574.0529]
#  [ -1.9974 574.0529]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 328682.9076716398
#
#
# 	 Training... Epoch 46
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 574.0529]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 567.6057]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 574.0529]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 580.5002]]
# [[0 1]]
# W_op
#  [[ -0.8772 145.4759]
#  [ -0.5413 145.958 ]
#  [ -0.6118 147.214 ]]
# W_hl
#  [[2036.6849 2050.1283 2085.7733]
#  [1990.8187 2004.3462 2039.9314]]
# B_op
#  [3.290000e-02 1.482995e+02]
# B_hl
#  [1990.1143 2003.8342 2039.1768]
# A_op
#  [[ -1.9974 586.9474]
#  [ -1.9974 586.9474]
#  [ -1.9974 586.9474]
#  [ -1.9974 586.9474]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 343634.0571759704
#
#
# 	 Training... Epoch 47
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 586.9474]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 580.5002]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 586.9474]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 593.3946]]
# [[0 1]]
# W_op
#  [[ -0.8772 148.6995]
#  [ -0.5413 149.1816]
#  [ -0.6118 150.4376]]
# W_hl
#  [[2128.8879 2142.6368 2179.0778]
#  [2082.     2095.8331 2132.2144]]
# B_op
#  [3.290000e-02 1.515231e+02]
# B_hl
#  [2081.2956 2095.3211 2131.4597]
# A_op
#  [[ -1.9974 599.8419]
#  [ -1.9974 599.8419]
#  [ -1.9974 599.8419]
#  [ -1.9974 599.8419]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 358917.7416431409
#
#
# 	 Training... Epoch 48
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 599.8419]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 593.3946]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 599.8419]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 606.2891]]
# [[0 1]]
# W_op
#  [[ -0.8772 151.9232]
#  [ -0.5413 152.4052]
#  [ -0.6118 153.6612]]
# W_hl
#  [[2223.1339 2237.1884 2274.4255]
#  [2175.2245 2189.3632 2226.5404]]
# B_op
#  [3.290000e-02 1.547468e+02]
# B_hl
#  [2174.5201 2188.8511 2225.7858]
# A_op
#  [[ -1.9974 612.7363]
#  [ -1.9974 612.7363]
#  [ -1.9974 612.7363]
#  [ -1.9974 612.7363]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 374533.9612456382
#
#
# 	 Training... Epoch 49
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 612.7363]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 606.2891]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 612.7363]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 619.1836]]
# [[0 1]]
# W_op
#  [[ -0.8772 155.1468]
#  [ -0.5413 155.6288]
#  [ -0.6118 156.8848]]
# W_hl
#  [[2319.4231 2333.7831 2371.8162]
#  [2270.4922 2284.9363 2322.9096]]
# B_op
#  [3.290000e-02 1.579704e+02]
# B_hl
#  [2269.7878 2284.4243 2322.155 ]
# A_op
#  [[ -1.9974 625.6308]
#  [ -1.9974 625.6308]
#  [ -1.9974 625.6308]
#  [ -1.9974 625.6308]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 390482.71598908823
#
#
# 	 Training... Epoch 50
# Passing samples in the range of 0 : 1
# A_op
#  [[ -1.9974 625.6308]]
# [[0 0]]
# Passing samples in the range of 1 : 2
# A_op
#  [[ -8.4447 619.1836]]
# [[1 1]]
# Passing samples in the range of 2 : 3
# A_op
#  [[ -1.9974 625.6308]]
# [[1 1]]
# Passing samples in the range of 3 : 4
# A_op
#  [[  4.4498 632.0781]]
# [[0 1]]
# W_op
#  [[ -0.8772 158.3704]
#  [ -0.5413 158.8525]
#  [ -0.6118 160.1084]]
# W_hl
#  [[2417.7555 2432.421  2471.2501]
#  [2367.803  2382.5526 2421.322 ]]
# B_op
#  [3.29000e-02 1.61194e+02]
# B_hl
#  [2367.0985 2382.0406 2420.5673]
# A_op
#  [[ -1.9974 638.5253]
#  [ -1.9974 638.5253]
#  [ -1.9974 638.5253]
#  [ -1.9974 638.5253]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 406764.00587911054
#
#
#
#
# Done! Final prediction result:
# A_op
#  [[ -1.9974 638.5253]
#  [ -1.9974 638.5253]
#  [ -1.9974 638.5253]
#  [ -1.9974 638.5253]]
# [[0 0]
#  [1 1]
#  [1 1]
#  [0 1]]
# Loss: 406764.00587911054
